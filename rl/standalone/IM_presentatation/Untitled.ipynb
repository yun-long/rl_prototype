# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
# fn = lambda x : 1/ ( 1 + np.exp(-(3 + 2 * x**2)) )
fn = lambda x: x **2 + 15 * np.sin(x)
x = np.linspace(-10, 12, 1000)
y = fn(x)
plt.plot(x, -y)
plt.show()
